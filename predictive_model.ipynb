# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('house_prices.csv')
df
# Out:
#       House_ID  Square_Feet  Bedrooms  Age   Price
# 0            1         1660         5   48  408062
# 1            2         4572         5   23  482986
# 2            3         3892         5    6   75457
# 3            4         1266         1   13  383811
# 4            5         4244         1   49  402895
# ...        ...          ...       ...  ...     ...
# 2995      2996         4706         4   13  114186
# 2996      2997         1089         4   22  317104
# 2997      2998         3280         5   31   68781
# 2998      2999         4052         2   22  287677
# 2999      3000         1078         5   37  307506
#
# [3000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# House_ID       0
# Square_Feet    0
# Bedrooms       0
# Age            0
# Price          0
# dtype: int64

# %%
df.describe()
# Out:
#           House_ID  Square_Feet     Bedrooms          Age          Price
# count  3000.000000  3000.000000  3000.000000  3000.000000    3000.000000
# mean   1500.500000  2943.929000     3.005333    24.727667  274817.961667
# std     866.169729  1200.752576     1.417265    14.070827  127460.378815
# min       1.000000   801.000000     1.000000     1.000000   50036.000000
# 25%     750.750000  1890.500000     2.000000    13.000000  165239.250000
# 50%    1500.500000  2951.000000     3.000000    25.000000  278809.000000
# 75%    2250.250000  3991.000000     4.000000    37.000000  382872.250000
# max    3000.000000  4999.000000     5.000000    49.000000  499732.000000

# %%
sns.pairplot(df, diag_kind= "kde")
plt.show()

# %%
x = df[['Square_Feet', 'Bedrooms', 'Age']] # define feature x
y = df['Price'] # target variable y

# %%
X_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42) #split data into train and test

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error (y_test, y_pred)

# %%
print(f'(mean_absolute_errro): {mae}')
print(f'(mean_squre_errro): {mse}')
# Out:
# (mean_absolute_errro): 106061.55175062308
# (mean_squre_errro): 15588425099.575834

# %%
plt.scatter(y_test, y_pred, alpha= 0.5)
plt.ylabel('actual value')
plt.xlabel('predicted value')
plt.title('actual value vs predicted value')
plt.show()
