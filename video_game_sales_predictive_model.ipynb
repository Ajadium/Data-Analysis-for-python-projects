# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('vgsales.csv')
df.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df = df.dropna(subset=["Year", "Publisher"])

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df['Year']= df['Year'].astype(int)

# %%
sales_columns = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]
df = df[~(df[sales_columns] == 0).all(axis=1)]

# %%
df.head(20)
# Out:
#     Rank                                          Name Platform  Year  \
# 0      1                                    Wii Sports      Wii  2006
# 1      2                             Super Mario Bros.      NES  1985
# 2      3                                Mario Kart Wii      Wii  2008
# 3      4                             Wii Sports Resort      Wii  2009
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996
# 5      6                                        Tetris       GB  1989
# 6      7                         New Super Mario Bros.       DS  2006
# 7      8                                      Wii Play      Wii  2006
# 8      9                     New Super Mario Bros. Wii      Wii  2009
# 9     10                                     Duck Hunt      NES  1984
# 10    11                                    Nintendogs       DS  2005
# 11    12                                 Mario Kart DS       DS  2005
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv("cleaned_vgsales.csv", index=False)
print("Cleaned data saved as 'cleaned_vgsales.csv'")
# Out:
# Cleaned data saved as 'cleaned_vgsales.csv'

# %%
df = pd.read_csv('cleaned_vgsales.csv')

# %%
df.head(20)
# Out:
#     Rank                                          Name Platform  Year  \
# 0      1                                    Wii Sports      Wii  2006
# 1      2                             Super Mario Bros.      NES  1985
# 2      3                                Mario Kart Wii      Wii  2008
# 3      4                             Wii Sports Resort      Wii  2009
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996
# 5      6                                        Tetris       GB  1989
# 6      7                         New Super Mario Bros.       DS  2006
# 7      8                                      Wii Play      Wii  2006
# 8      9                     New Super Mario Bros. Wii      Wii  2009
# 9     10                                     Duck Hunt      NES  1984
# 10    11                                    Nintendogs       DS  2005
# 11    12                                 Mario Kart DS       DS  2005
# ...

# %%
sns.pairplot(df, diag_kind='kde')
plt.title('video_game_visuals')
plt.show()

# %%
 # predicting whether a game will be a "hit" (e.g. if Global_Sales > 1.0 million) - classification problem.

# %%
#selecting the features
X = df[["Platform", "Year", "Genre", "Publisher", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]]
y = df["Global_Sales"]

# %%
#encoding
X_encoded = pd.get_dummies(X, columns=["Platform", "Genre", "Publisher"], drop_first=True)

# %%
#Train-Test split
X_test, x_train, y_test, y_train = train_test_split(X_encoded,y, test_size=0.2, random_state=42)

# %%
#train mdoel
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
#Evaluate the model
y_pred = model.predict(x_train)

# %%
mse = mean_squared_error(y_train,y_pred)
r2 = r2_score(y_train,y_pred)

print(f'mean_squared_error: {mse:.3f}')
print(f'r2_score: {r2:.3f}')
# Out:
# mean_squared_error: 0.142
# r2_score: 0.967

# %%
import joblib
joblib.dump(model, "sales_model.pkl")
# Out:
# ['sales_model.pkl']
